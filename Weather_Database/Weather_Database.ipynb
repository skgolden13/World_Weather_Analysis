# %%
# Import dependencies.
import pandas as pd
import requests
import numpy as np
from citipy import citipy
from config import weather_api_key
import time

# Generate open weather url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data =[]

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
time.sleep(60)

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | urumqi
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | lafayette
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | narsaq
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | parabel
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | tiarei
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | sakakah
# Processing Record 19 of Set 1 | ouadda
# Processing Record 20 of Set 1 | meulaboh
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | jakoruda
# City not found. Skipping...
# Processing Record 32 of Set 1 | lewisporte
# Processing Record 33 of Set 1 | mehamn
# Processing Record 34 of Set 1 | tawang
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | bambous virieux
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | salalah
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | yambio
# Processing Record 43 of Set 1 | bullhead city
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | goderich
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | akdepe
# Processing Record 48 of Set 1 | laguna
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | north bend
# Processing Record 2 of Set 2 | yulara
# Processing Record 3 of Set 2 | flin flon
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | hue
# Processing Record 9 of Set 2 | kijang
# Processing Record 10 of Set 2 | lengshuijiang
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | alikalia
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | cullman
# Processing Record 18 of Set 2 | tokur
# Processing Record 19 of Set 2 | iralaya
# Processing Record 20 of Set 2 | ciudad del maiz
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | kudat
# Processing Record 24 of Set 2 | rantauprapat
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | dongning
# Processing Record 27 of Set 2 | dzilam gonzalez
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | turochak
# Processing Record 30 of Set 2 | pozo colorado
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | mesolongion
# City not found. Skipping...
# Processing Record 33 of Set 2 | beidao
# Processing Record 34 of Set 2 | nuuk
# Processing Record 35 of Set 2 | bubaque
# Processing Record 36 of Set 2 | maceio
# Processing Record 37 of Set 2 | baruun-urt
# Processing Record 38 of Set 2 | lorengau
# Processing Record 39 of Set 2 | maputo
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 42 of Set 2 | hovd
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | luebo
# Processing Record 45 of Set 2 | berestechko
# Processing Record 46 of Set 2 | japura
# Processing Record 47 of Set 2 | arti
# Processing Record 48 of Set 2 | hami
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | leuna
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | pringsewu
# Processing Record 5 of Set 3 | muli
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 3 | nicoya
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | lata
# Processing Record 11 of Set 3 | gaborone
# Processing Record 12 of Set 3 | birjand
# Processing Record 13 of Set 3 | umm lajj
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | yar-sale
# Processing Record 16 of Set 3 | carbonia
# Processing Record 17 of Set 3 | havoysund
# Processing Record 18 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 3 | svarstad
# Processing Record 20 of Set 3 | saint anthony
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | punta arenas
# Processing Record 23 of Set 3 | mitsamiouli
# Processing Record 24 of Set 3 | kemijarvi
# Processing Record 25 of Set 3 | tessalit
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | esperance
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | soe
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | tiruvottiyur
# City not found. Skipping...
# Processing Record 33 of Set 3 | high level
# Processing Record 34 of Set 3 | ngunguru
# Processing Record 35 of Set 3 | grand gaube
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | baykit
# Processing Record 38 of Set 3 | torbay
# Processing Record 39 of Set 3 | yellandu
# Processing Record 40 of Set 3 | isangel
# Processing Record 41 of Set 3 | panjab
# Processing Record 42 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 3 | shenkursk
# Processing Record 45 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 3 | acapulco
# Processing Record 47 of Set 3 | talnakh
# Processing Record 48 of Set 3 | ufimskiy
# Processing Record 49 of Set 3 | los llanos de aridane
# Processing Record 50 of Set 3 | ugoofaaru
# Processing Record 1 of Set 4 | te anau
# Processing Record 2 of Set 4 | phangnga
# Processing Record 3 of Set 4 | yurimaguas
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | emba
# Processing Record 7 of Set 4 | saint-paul
# Processing Record 8 of Set 4 | broome
# Processing Record 9 of Set 4 | amboise
# Processing Record 10 of Set 4 | roma
# Processing Record 11 of Set 4 | codrington
# Processing Record 12 of Set 4 | mahebourg
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | neiafu
# Processing Record 16 of Set 4 | bowen
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | moron
# Processing Record 19 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 4 | sao miguel do araguaia
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | cockburn town
# Processing Record 23 of Set 4 | toora-khem
# Processing Record 24 of Set 4 | chara
# Processing Record 25 of Set 4 | hilo
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | fez
# Processing Record 28 of Set 4 | puri
# Processing Record 29 of Set 4 | saskylakh
# Processing Record 30 of Set 4 | aykhal
# Processing Record 31 of Set 4 | praia da vitoria
# Processing Record 32 of Set 4 | cabo san lucas
# Processing Record 33 of Set 4 | port moresby
# Processing Record 34 of Set 4 | sirari
# Processing Record 35 of Set 4 | jacareacanga
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | ashland
# Processing Record 38 of Set 4 | imbituba
# Processing Record 39 of Set 4 | souillac
# Processing Record 40 of Set 4 | biltine
# Processing Record 41 of Set 4 | barra do garcas
# Processing Record 42 of Set 4 | nemuro
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | iquique
# Processing Record 45 of Set 4 | husavik
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | itacarambi
# Processing Record 48 of Set 4 | maumere
# Processing Record 49 of Set 4 | thanh hoa
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | dalvik
# Processing Record 2 of Set 5 | wattegama
# Processing Record 3 of Set 5 | svetlyy
# Processing Record 4 of Set 5 | namatanai
# Processing Record 5 of Set 5 | serenje
# Processing Record 6 of Set 5 | andros town
# Processing Record 7 of Set 5 | mehnagar
# Processing Record 8 of Set 5 | ulaanbaatar
# Processing Record 9 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 5 | dikson
# Processing Record 11 of Set 5 | halifax
# Processing Record 12 of Set 5 | faya
# Processing Record 13 of Set 5 | grindavik
# Processing Record 14 of Set 5 | saint-pierre
# Processing Record 15 of Set 5 | bonavista
# Processing Record 16 of Set 5 | seredka
# Processing Record 17 of Set 5 | mogok
# Processing Record 18 of Set 5 | srandakan
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | port-gentil
# Processing Record 21 of Set 5 | chimoio
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | mount isa
# Processing Record 25 of Set 5 | sangar
# Processing Record 26 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 5 | muros
# Processing Record 28 of Set 5 | tamandare
# Processing Record 29 of Set 5 | christchurch
# Processing Record 30 of Set 5 | saint-philippe
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | keti bandar
# Processing Record 34 of Set 5 | woodward
# Processing Record 35 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 5 | ahipara
# Processing Record 37 of Set 5 | nizhniy kuranakh
# Processing Record 38 of Set 5 | barrow
# Processing Record 39 of Set 5 | colesberg
# Processing Record 40 of Set 5 | tiksi
# Processing Record 41 of Set 5 | saravan
# Processing Record 42 of Set 5 | rio pardo de minas
# Processing Record 43 of Set 5 | nishihara
# Processing Record 44 of Set 5 | lewistown
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | vilcun
# Processing Record 47 of Set 5 | ucluelet
# Processing Record 48 of Set 5 | malayal
# Processing Record 49 of Set 5 | dunedin
# Processing Record 50 of Set 5 | astorga
# Processing Record 1 of Set 6 | tocopilla
# Processing Record 2 of Set 6 | axim
# Processing Record 3 of Set 6 | kaeo
# Processing Record 4 of Set 6 | aklavik
# Processing Record 5 of Set 6 | yerbogachen
# Processing Record 6 of Set 6 | cayenne
# Processing Record 7 of Set 6 | mugur-aksy
# Processing Record 8 of Set 6 | cap malheureux
# Processing Record 9 of Set 6 | katangli
# Processing Record 10 of Set 6 | neyshabur
# Processing Record 11 of Set 6 | mahon
# Processing Record 12 of Set 6 | tilichiki
# Processing Record 13 of Set 6 | chokurdakh
# Processing Record 14 of Set 6 | altay
# Processing Record 15 of Set 6 | enid
# Processing Record 16 of Set 6 | tezu
# Processing Record 17 of Set 6 | barcelos
# Processing Record 18 of Set 6 | bathsheba
# Processing Record 19 of Set 6 | malanje
# Processing Record 20 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 6 | amapa
# Processing Record 22 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | lebu
# Processing Record 25 of Set 6 | ballina
# Processing Record 26 of Set 6 | udachnyy
# Processing Record 27 of Set 6 | zhigansk
# Processing Record 28 of Set 6 | havre-saint-pierre
# Processing Record 29 of Set 6 | margate
# Processing Record 30 of Set 6 | saint-joseph
# Processing Record 31 of Set 6 | idrinskoye
# Processing Record 32 of Set 6 | hambantota
# Processing Record 33 of Set 6 | lyubech
# Processing Record 34 of Set 6 | sorland
# Processing Record 35 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 6 | beyneu
# Processing Record 37 of Set 6 | alyangula
# Processing Record 38 of Set 6 | zabid
# Processing Record 39 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 6 | adrar
# Processing Record 41 of Set 6 | mirebalais
# Processing Record 42 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 6 | gizo
# Processing Record 44 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 6 | mayya
# Processing Record 46 of Set 6 | panzos
# Processing Record 47 of Set 6 | san quintin
# Processing Record 48 of Set 6 | sao filipe
# Processing Record 49 of Set 6 | chuy
# Processing Record 50 of Set 6 | kinablangan
# Processing Record 1 of Set 7 | warwick
# Processing Record 2 of Set 7 | porto belo
# Processing Record 3 of Set 7 | yarada
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | umm kaddadah
# Processing Record 6 of Set 7 | la asuncion
# Processing Record 7 of Set 7 | chimbote
# Processing Record 8 of Set 7 | benguela
# Processing Record 9 of Set 7 | san clemente
# Processing Record 10 of Set 7 | lavrentiya
# Processing Record 11 of Set 7 | jalingo
# Processing Record 12 of Set 7 | muyezerskiy
# Processing Record 13 of Set 7 | sitka
# Processing Record 14 of Set 7 | khilok
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 7 | maunabo
# Processing Record 17 of Set 7 | beringovskiy
# Processing Record 18 of Set 7 | san cristobal
# Processing Record 19 of Set 7 | acarau
# Processing Record 20 of Set 7 | monrovia
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | mongu
# Processing Record 23 of Set 7 | sungaipenuh
# Processing Record 24 of Set 7 | atasu
# Processing Record 25 of Set 7 | maniitsoq
# Processing Record 26 of Set 7 | koungou
# Processing Record 27 of Set 7 | alexandria
# Processing Record 28 of Set 7 | matagami
# Processing Record 29 of Set 7 | tongsa
# City not found. Skipping...
# Processing Record 30 of Set 7 | belmonte
# Processing Record 31 of Set 7 | kvarkeno
# Processing Record 32 of Set 7 | samarai
# Processing Record 33 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 34 of Set 7 | chalus
# Processing Record 35 of Set 7 | hamilton
# Processing Record 36 of Set 7 | elizabeth city
# Processing Record 37 of Set 7 | keetmanshoop
# Processing Record 38 of Set 7 | fortuna
# Processing Record 39 of Set 7 | eureka
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | boende
# Processing Record 42 of Set 7 | paita
# Processing Record 43 of Set 7 | richards bay
# Processing Record 44 of Set 7 | sistranda
# Processing Record 45 of Set 7 | pangnirtung
# Processing Record 46 of Set 7 | portland
# Processing Record 47 of Set 7 | edmundston
# Processing Record 48 of Set 7 | sidi ali
# Processing Record 49 of Set 7 | mineiros
# Processing Record 50 of Set 7 | orthez
# Processing Record 1 of Set 8 | kruisfontein
# Processing Record 2 of Set 8 | suntar
# Processing Record 3 of Set 8 | luderitz
# Processing Record 4 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 8 | dryden
# Processing Record 6 of Set 8 | masuri
# Processing Record 7 of Set 8 | montfermeil
# Processing Record 8 of Set 8 | gornopravdinsk
# Processing Record 9 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | inirida
# Processing Record 11 of Set 8 | tabou
# Processing Record 12 of Set 8 | yoichi
# Processing Record 13 of Set 8 | pandan niog
# Processing Record 14 of Set 8 | canico
# Processing Record 15 of Set 8 | artyom
# Processing Record 16 of Set 8 | medea
# Processing Record 17 of Set 8 | falakata
# Processing Record 18 of Set 8 | mandalgovi
# Processing Record 19 of Set 8 | mahajanga
# Processing Record 20 of Set 8 | lianzhou
# Processing Record 21 of Set 8 | makungu
# Processing Record 22 of Set 8 | humaita
# Processing Record 23 of Set 8 | tibu
# Processing Record 24 of Set 8 | grong
# Processing Record 25 of Set 8 | pitea
# Processing Record 26 of Set 8 | sorong
# Processing Record 27 of Set 8 | vytegra
# Processing Record 28 of Set 8 | kuruman
# Processing Record 29 of Set 8 | boddam
# Processing Record 30 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 8 | harlingen
# Processing Record 32 of Set 8 | milkovo
# Processing Record 33 of Set 8 | panama city
# Processing Record 34 of Set 8 | nabire
# Processing Record 35 of Set 8 | simao
# Processing Record 36 of Set 8 | atkinson
# Processing Record 37 of Set 8 | chusovoy
# Processing Record 38 of Set 8 | paamiut
# Processing Record 39 of Set 8 | igrim
# Processing Record 40 of Set 8 | dwarka
# Processing Record 41 of Set 8 | westport
# Processing Record 42 of Set 8 | clyde river
# Processing Record 43 of Set 8 | poum
# Processing Record 44 of Set 8 | brae
# Processing Record 45 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 8 | vostok
# Processing Record 47 of Set 8 | syamzha
# Processing Record 48 of Set 8 | deputatskiy
# Processing Record 49 of Set 8 | lamu
# Processing Record 50 of Set 8 | saint george
# Processing Record 1 of Set 9 | berlevag
# Processing Record 2 of Set 9 | barmer
# Processing Record 3 of Set 9 | zyryanka
# Processing Record 4 of Set 9 | wageningen
# Processing Record 5 of Set 9 | ixtapa
# Processing Record 6 of Set 9 | thongwa
# Processing Record 7 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 8 of Set 9 | puerto del rosario
# Processing Record 9 of Set 9 | santa rosa
# Processing Record 10 of Set 9 | hirara
# Processing Record 11 of Set 9 | voyinka
# Processing Record 12 of Set 9 | mataruska banja
# Processing Record 13 of Set 9 | mankono
# Processing Record 14 of Set 9 | prince rupert
# Processing Record 15 of Set 9 | iqaluit
# Processing Record 16 of Set 9 | havelock
# Processing Record 17 of Set 9 | uvalde
# Processing Record 18 of Set 9 | hede
# Processing Record 19 of Set 9 | kenai
# Processing Record 20 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | danville
# Processing Record 22 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 9 | anadyr
# Processing Record 24 of Set 9 | tura
# Processing Record 25 of Set 9 | tucuma
# Processing Record 26 of Set 9 | mogzon
# Processing Record 27 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 9 | horsham
# Processing Record 29 of Set 9 | beloha
# Processing Record 30 of Set 9 | dauphin
# Processing Record 31 of Set 9 | albanel
# Processing Record 32 of Set 9 | san policarpo
# Processing Record 33 of Set 9 | reshetylivka
# Processing Record 34 of Set 9 | honiara
# Processing Record 35 of Set 9 | boundiali
# Processing Record 36 of Set 9 | san bartolome
# Processing Record 37 of Set 9 | turukhansk
# Processing Record 38 of Set 9 | cedartown
# Processing Record 39 of Set 9 | phek
# Processing Record 40 of Set 9 | wuxi
# Processing Record 41 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 9 | tandalti
# Processing Record 43 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 9 | mwinilunga
# Processing Record 45 of Set 9 | pingzhuang
# Processing Record 46 of Set 9 | lithgow
# Processing Record 47 of Set 9 | chaumont
# Processing Record 48 of Set 9 | bilibino
# Processing Record 49 of Set 9 | hallein
# Processing Record 50 of Set 9 | sesheke
# Processing Record 1 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 10 | serebryansk
# Processing Record 3 of Set 10 | warmbad
# Processing Record 4 of Set 10 | auki
# Processing Record 5 of Set 10 | ambon
# Processing Record 6 of Set 10 | arlit
# Processing Record 7 of Set 10 | bakchar
# Processing Record 8 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 9 of Set 10 | tongling
# Processing Record 10 of Set 10 | virginia beach
# Processing Record 11 of Set 10 | viedma
# Processing Record 12 of Set 10 | puerto escondido
# Processing Record 13 of Set 10 | khash
# Processing Record 14 of Set 10 | batemans bay
# Processing Record 15 of Set 10 | roald
# Processing Record 16 of Set 10 | senanga
# Processing Record 17 of Set 10 | guerrero negro
# Processing Record 18 of Set 10 | llanes
# Processing Record 19 of Set 10 | trelew
# Processing Record 20 of Set 10 | palmer
# Processing Record 21 of Set 10 | verkhnyaya inta
# Processing Record 22 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 10 | oromocto
# Processing Record 24 of Set 10 | aksu
# Processing Record 25 of Set 10 | la macarena
# Processing Record 26 of Set 10 | kahului
# Processing Record 27 of Set 10 | stromness
# Processing Record 28 of Set 10 | agadir
# Processing Record 29 of Set 10 | champerico
# Processing Record 30 of Set 10 | tahoua
# Processing Record 31 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 10 | kadhan
# Processing Record 33 of Set 10 | almaznyy
# Processing Record 34 of Set 10 | ambovombe
# Processing Record 35 of Set 10 | natal
# Processing Record 36 of Set 10 | netarhat
# Processing Record 37 of Set 10 | santa cruz
# Processing Record 38 of Set 10 | banka
# Processing Record 39 of Set 10 | yazman
# Processing Record 40 of Set 10 | nova ushytsya
# Processing Record 41 of Set 10 | bogorodskoye
# Processing Record 42 of Set 10 | merauke
# Processing Record 43 of Set 10 | kysyl-syr
# Processing Record 44 of Set 10 | kukes
# Processing Record 45 of Set 10 | garissa
# Processing Record 46 of Set 10 | formosa do rio preto
# Processing Record 47 of Set 10 | litein
# Processing Record 48 of Set 10 | caravelas
# Processing Record 49 of Set 10 | benghazi
# Processing Record 50 of Set 10 | saldanha
# Processing Record 1 of Set 11 | vitoria
# Processing Record 2 of Set 11 | archidona
# Processing Record 3 of Set 11 | saint-augustin
# Processing Record 4 of Set 11 | novobirilyussy
# Processing Record 5 of Set 11 | churapcha
# Processing Record 6 of Set 11 | rocha
# Processing Record 7 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 11 | port hardy
# Processing Record 9 of Set 11 | zhoucheng
# Processing Record 10 of Set 11 | port blair
# Processing Record 11 of Set 11 | qaqortoq
# Processing Record 12 of Set 11 | dudinka
# Processing Record 13 of Set 11 | yanam
# Processing Record 14 of Set 11 | kushima
# Processing Record 15 of Set 11 | sur
# Processing Record 16 of Set 11 | yumen
# Processing Record 17 of Set 11 | homer
# Processing Record 18 of Set 11 | san rafael del sur
# Processing Record 19 of Set 11 | fatehpur
# Processing Record 20 of Set 11 | pontianak
# Processing Record 21 of Set 11 | padang
# Processing Record 22 of Set 11 | port keats
# Processing Record 23 of Set 11 | bon accord
# Processing Record 24 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 11 | horodyshche
# Processing Record 26 of Set 11 | manaure
# Processing Record 27 of Set 11 | sinnamary
# Processing Record 28 of Set 11 | lardos
# Processing Record 29 of Set 11 | dehui
# Processing Record 30 of Set 11 | kilinochchi
# Processing Record 31 of Set 11 | coihaique
# Processing Record 32 of Set 11 | hoi an
# Processing Record 33 of Set 11 | bocas del toro
# Processing Record 34 of Set 11 | nuevitas
# Processing Record 35 of Set 11 | emerald
# Processing Record 36 of Set 11 | lasa
# Processing Record 37 of Set 11 | mitu
# Processing Record 38 of Set 11 | hit
# Processing Record 39 of Set 11 | iracoubo
# Processing Record 40 of Set 11 | tshikapa
# Processing Record 41 of Set 11 | la seyne-sur-mer
# Processing Record 42 of Set 11 | tiznit
# Processing Record 43 of Set 11 | severo-yeniseyskiy
# Processing Record 44 of Set 11 | olafsvik
# Processing Record 45 of Set 11 | namie
# Processing Record 46 of Set 11 | srednekolymsk
# Processing Record 47 of Set 11 | port hawkesbury
# Processing Record 48 of Set 11 | oildale
# Processing Record 49 of Set 11 | luanda
# Processing Record 50 of Set 11 | lakes entrance
# Processing Record 1 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 12 | naryan-mar
# Processing Record 3 of Set 12 | half moon bay
# Processing Record 4 of Set 12 | hammerfest
# Processing Record 5 of Set 12 | lucapa
# Processing Record 6 of Set 12 | besikduzu
# Processing Record 7 of Set 12 | tarakan
# Processing Record 8 of Set 12 | oppdal
# Processing Record 9 of Set 12 | miles city
# Processing Record 10 of Set 12 | amahai
# Processing Record 11 of Set 12 | shiraoi
# Processing Record 12 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 12 | topeka
# Processing Record 14 of Set 12 | kieta
# Processing Record 15 of Set 12 | damietta
# Processing Record 16 of Set 12 | ola
# Processing Record 17 of Set 12 | fairview
# Processing Record 18 of Set 12 | sola
# Processing Record 19 of Set 12 | touros
# Processing Record 20 of Set 12 | cabedelo
# Processing Record 21 of Set 12 | harper
# Processing Record 22 of Set 12 | grand baie
# Processing Record 23 of Set 12 | sabang
# Processing Record 24 of Set 12 | karaton
# Processing Record 25 of Set 12 | ojinaga
# Processing Record 26 of Set 12 | sremska mitrovica
# Processing Record 27 of Set 12 | ust-maya
# Processing Record 28 of Set 12 | ust-karsk
# Processing Record 29 of Set 12 | uslar
# Processing Record 30 of Set 12 | medicine hat
# Processing Record 31 of Set 12 | areka
# Processing Record 32 of Set 12 | sarahan
# Processing Record 33 of Set 12 | hude
# Processing Record 34 of Set 12 | aksarka
# Processing Record 35 of Set 12 | karakulino
# Processing Record 36 of Set 12 | oktyabrskiy
# Processing Record 37 of Set 12 | haapu
# City not found. Skipping...
# Processing Record 38 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 12 | hohhot
# Processing Record 40 of Set 12 | teya
# Processing Record 41 of Set 12 | astoria
# Processing Record 42 of Set 12 | nevesinje
# Processing Record 43 of Set 12 | marsh harbour
# Processing Record 44 of Set 12 | pochutla
# Processing Record 45 of Set 12 | lompoc
# Processing Record 46 of Set 12 | coquimbo
# Processing Record 47 of Set 12 | les cayes
# Processing Record 48 of Set 12 | touho
# Processing Record 49 of Set 12 | oil city
# Processing Record 50 of Set 12 | college
# Processing Record 1 of Set 13 | stuttgart
# Processing Record 2 of Set 13 | broken hill
# Processing Record 3 of Set 13 | ewa beach
# Processing Record 4 of Set 13 | lovozero
# Processing Record 5 of Set 13 | mucurici
# Processing Record 6 of Set 13 | san javier
# Processing Record 7 of Set 13 | bereda
# Processing Record 8 of Set 13 | alice springs
# Processing Record 9 of Set 13 | hofn
# Processing Record 10 of Set 13 | formiga
# Processing Record 11 of Set 13 | kamina
# Processing Record 12 of Set 13 | san pedro buenavista
# Processing Record 13 of Set 13 | pangody
# Processing Record 14 of Set 13 | nalut
# Processing Record 15 of Set 13 | waingapu
# Processing Record 16 of Set 13 | pisco
# Processing Record 17 of Set 13 | sibolga
# Processing Record 18 of Set 13 | korla
# Processing Record 19 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 13 | chernyshevskiy
# Processing Record 21 of Set 13 | vanavara
# Processing Record 22 of Set 13 | sezana
# Processing Record 23 of Set 13 | mochudi
# Processing Record 24 of Set 13 | eydhafushi
# Processing Record 25 of Set 13 | matay
# Processing Record 26 of Set 13 | san patricio
# Processing Record 27 of Set 13 | ossora
# Processing Record 28 of Set 13 | motygino
# Processing Record 29 of Set 13 | trincomalee
# Processing Record 30 of Set 13 | mahibadhoo
# Processing Record 31 of Set 13 | nelson bay
# Processing Record 32 of Set 13 | zhaotong
# Processing Record 33 of Set 13 | juneau
# Processing Record 34 of Set 13 | diego de almagro
# Processing Record 35 of Set 13 | zabol
# Processing Record 36 of Set 13 | marondera
# Processing Record 37 of Set 13 | severo-kurilsk
# Processing Record 38 of Set 13 | pangkalanbuun
# Processing Record 39 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 13 | kalabo
# Processing Record 41 of Set 13 | nome
# Processing Record 42 of Set 13 | blagoyevo
# Processing Record 43 of Set 13 | martapura
# Processing Record 44 of Set 13 | chaa-khol
# City not found. Skipping...
# Processing Record 45 of Set 13 | aiquile
# Processing Record 46 of Set 13 | at-bashi
# Processing Record 47 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 13 | whitecourt
# Processing Record 49 of Set 13 | ketchikan
# Processing Record 50 of Set 13 | gorontalo
# Processing Record 1 of Set 14 | mumbwa
# Processing Record 2 of Set 14 | necochea
# Processing Record 3 of Set 14 | jhunjhunun
# Processing Record 4 of Set 14 | sirjan
# Processing Record 5 of Set 14 | tommot
# Processing Record 6 of Set 14 | santa barbara
# Processing Record 7 of Set 14 | isabela
# Processing Record 8 of Set 14 | itoman
# Processing Record 9 of Set 14 | galesong
# Processing Record 10 of Set 14 | ufa
# Processing Record 11 of Set 14 | avera
# Processing Record 12 of Set 14 | sydney
# Processing Record 13 of Set 14 | aurillac
# Processing Record 14 of Set 14 | bandipur
# Processing Record 15 of Set 14 | pingliang
# Processing Record 16 of Set 14 | kampong thum
# Processing Record 17 of Set 14 | alakurtti
# Processing Record 18 of Set 14 | lufilufi
# Processing Record 19 of Set 14 | bardiyah
# Processing Record 20 of Set 14 | velizh
# Processing Record 21 of Set 14 | ardakan
# Processing Record 22 of Set 14 | constantine
# Processing Record 23 of Set 14 | la union
# Processing Record 24 of Set 14 | chippewa falls
# Processing Record 25 of Set 14 | fort nelson
# Processing Record 26 of Set 14 | ascension
# Processing Record 27 of Set 14 | morondava
# Processing Record 28 of Set 14 | bolobo
# Processing Record 29 of Set 14 | tucuman
# Processing Record 30 of Set 14 | kajaani
# Processing Record 31 of Set 14 | lady frere
# Processing Record 32 of Set 14 | mabaruma
# Processing Record 33 of Set 14 | kirkwood
# Processing Record 34 of Set 14 | podlesnoye
# Processing Record 35 of Set 14 | zafarabad
# Processing Record 36 of Set 14 | esterhazy
# Processing Record 37 of Set 14 | yenagoa
# Processing Record 38 of Set 14 | pakxan
# Processing Record 39 of Set 14 | samfya
# Processing Record 40 of Set 14 | mundo nuevo
# Processing Record 41 of Set 14 | komsomolskiy
# Processing Record 42 of Set 14 | riyadh
# Processing Record 43 of Set 14 | abu samrah
# Processing Record 44 of Set 14 | llangefni
# Processing Record 45 of Set 14 | sonqor
# Processing Record 46 of Set 14 | san carlos
# Processing Record 47 of Set 14 | kamenka
# Processing Record 48 of Set 14 | morehead
# Processing Record 49 of Set 14 | hualmay
# Processing Record 50 of Set 14 | troitskaya
# Processing Record 1 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 15 | mount gambier
# Processing Record 3 of Set 15 | samana
# Processing Record 4 of Set 15 | calama
# Processing Record 5 of Set 15 | dutse
# Processing Record 6 of Set 15 | rincon
# Processing Record 7 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 8 of Set 15 | nioro
# Processing Record 9 of Set 15 | longonjo
# Processing Record 10 of Set 15 | jaisalmer
# Processing Record 11 of Set 15 | hurghada
# Processing Record 12 of Set 15 | noyabrsk
# Processing Record 13 of Set 15 | bilma
# Processing Record 14 of Set 15 | otautau
# Processing Record 15 of Set 15 | shelburne
# Processing Record 16 of Set 15 | barnala
# Processing Record 17 of Set 15 | northam
# Processing Record 18 of Set 15 | aljezur
# Processing Record 19 of Set 15 | ostrovnoy
# Processing Record 20 of Set 15 | solnechnyy
# Processing Record 21 of Set 15 | tunxi
# City not found. Skipping...
# Processing Record 22 of Set 15 | shirokiy
# Processing Record 23 of Set 15 | de aar
# Processing Record 24 of Set 15 | lima
# Processing Record 25 of Set 15 | honningsvag
# Processing Record 26 of Set 15 | vilya
# Processing Record 27 of Set 15 | pemangkat
# Processing Record 28 of Set 15 | kavaratti
# Processing Record 29 of Set 15 | khani
# Processing Record 30 of Set 15 | urucui
# Processing Record 31 of Set 15 | nizwa
# Processing Record 32 of Set 15 | boa vista
# Processing Record 33 of Set 15 | mangan
# Processing Record 34 of Set 15 | kantemirovka
# Processing Record 35 of Set 15 | taga dzong
# City not found. Skipping...
# Processing Record 36 of Set 15 | mancio lima
# Processing Record 37 of Set 15 | olinda
# Processing Record 38 of Set 15 | coahuayana
# Processing Record 39 of Set 15 | izyum
# Processing Record 40 of Set 15 | clarksburg
# Processing Record 41 of Set 15 | lithakia
# Processing Record 42 of Set 15 | oranjemund
# Processing Record 43 of Set 15 | kundiawa
# Processing Record 44 of Set 15 | bandrele
# Processing Record 45 of Set 15 | karratha
# Processing Record 46 of Set 15 | armeria
# Processing Record 47 of Set 15 | kishi
# Processing Record 48 of Set 15 | guigue
# Processing Record 49 of Set 15 | vagur
# Processing Record 50 of Set 15 | gulabpura
# Processing Record 1 of Set 16 | shchors
# Processing Record 2 of Set 16 | kurchum
# Processing Record 3 of Set 16 | mackay
# Processing Record 4 of Set 16 | caetes
# Processing Record 5 of Set 16 | fuerte olimpo
# Processing Record 6 of Set 16 | yakeshi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Lincoln      AU -34.7333  135.8667     75.92        45           4
# 1      Cidreira      BR -30.1811  -50.2056     70.90        95          11
# 2     Cape Town      ZA -33.9258   18.4232     59.92        87           0
# 3   Provideniya      RU  64.3833 -173.3000     32.36        80          20
# 4        Urumqi      CN  43.8010   87.6005     52.75        58          20
#
#    Wind Speed Current Description
# 0       16.60           clear sky
# 1        3.85          few clouds
# 2       11.01           clear sky
# 3        2.24          few clouds
# 4        4.47          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
